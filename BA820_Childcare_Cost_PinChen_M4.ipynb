# %% [markdown]
# # **B1 Team 11**
# ## Childcare EDA — Anna Wei, Nan Li, Pin-Chen Kuo, Stephanie Chen

# %% [markdown]
# # **Data Dictionary**

# %% [markdown]
# ### **childcare_costs.csv**
# | variable | class | description |
# | :--- | :--- | :--- |
# | county_fips_code | number | Four- or five-digit number that uniquely identifies the county in a state. <br>The first two digits (for five-digit numbers) or 1 digit (for four-digit numbers) refer to the FIPS code of the state to which the county belongs. |
# | study_year | number | Year the data collection began for the market rate survey and in which ACS data is representative of, or the study publication date. |
# | unr_16 | number | Unemployment rate of the population aged 16 years old or older. |
# | funr_16 | number | Unemployment rate of the female population aged 16 years old or older. |
# | munr_16 | number | Unemployment rate of the male population aged 16 years old or older. |
# | unr_20to64 | number | Unemployment rate of the population aged 20 to 64 years old. |
# | funr_20to64 | number | Unemployment rate of the female population aged 20 to 64 years old. |
# | munr_20to64 | number | Unemployment rate of the male population aged 20 to 64 years old. |
# | flfpr_20to64 | number | Labor force participation rate of the female population aged 20 to 64 years old. |
# | flfpr_20to64_under6 | number | Labor force participation rate of the female population aged 20 to 64 years old who have children under 6 years old. |
# | flfpr_20to64_6to17 | number | Labor force participation rate of the female population aged 20 to 64 years old who have children between 6 and 17 years old. |
# | flfpr_20to64_under6_6to17 | number | Labor force participation rate of the female population aged 20 to 64 years old who have children under 6 years old and between 6 and 17 years old. |
# | mlfpr_20to64 | number | Labor force participation rate of the male population aged 20 to 64 years old. |
# | pr_f | number | Poverty rate for families. |
# | pr_p | number | Poverty rate for individuals. |
# | mhi_2018 | number | Median household income expressed in 2018 dollars. |
# | me_2018 | number | Median earnings expressed in 2018 dollars for the population aged 16 years old or older. |
# | fme_2018 | number | Median earnings for females expressed in 2018 dollars for the population aged 16 years old or older. |
# | mme_2018 | number | Median earnings for males expressed in 2018 dollars for the population aged 16 years old or older. |
# | total_pop | number | Count of the total population. |
# | one_race | number | Percent of population that identifies as being one race. |
# | one_race_w | number | Percent of population that identifies as being one race and being only White or Caucasian. |
# | one_race_b | number | Percent of population that identifies as being one race and being only Black or African American. |
# | one_race_i | number | Percent of population that identifies as being one race and being only American Indian or Alaska Native. |
# | one_race_a | number | Percent of population that identifies as being one race and being only Asian. |
# | one_race_h | number | Percent of population that identifies as being one race and being only Native Hawaiian or Pacific Islander. |
# | one_race_other | number | Percent of population that identifies as being one race and being a different race not previously mentioned. |
# | two_races | number | Percent of population that identifies as being two or more races. |
# | hispanic | number | Percent of population that identifies as being Hispanic or Latino regardless of race. |
# | households | number | Number of households. |
# | h_under6_both_work | number | Number of households with children under 6 years old with two parents that are both working. |
# | h_under6_f_work | number | Number of households with children under 6 years old with two parents with only the father working. |
# | h_under6_m_work | number | Number of households with children under 6 years old with two parents with only the mother working. |
# | h_under6_single_m | number | Number of households with children under 6 years old with a single mother. |
# | h_6to17_both_work | number | Number of households with children between 6 and 17 years old with two parents that are both working. |
# | h_6to17_fwork | number | Number of households with children between 6 and 17 years old with two parents with only the father working. |
# | h_6to17_mwork | number | Number of households with children between 6 and 17 years old with two parents with only the mother working. |
# | h_6to17_single_m | number | Number of households with children between 6 and 17 years old with a single mother. |
# | emp_m | number | Percent of civilians employed in management, business, science, and arts occupations aged 16 years old or older in the county. |
# | memp_m | number | Percent of male civilians employed in management, business, science, and arts occupations aged 16 years old or older in the county. |
# | femp_m | number | Percent of female civilians employed in management, business, science, and arts occupations aged 16 years old or older in the county. |
# | emp_service | number | Percent of civilians employed in service occupations aged 16 years old and older in the county. |
# | memp_service | number | Percent of male civilians employed in service occupations aged 16 years old and older in the county. |
# | femp_service | number | Percent of female civilians employed in service occupations aged 16 years old and older in the county. |
# | emp_sales | number | Percent of civilians employed in sales and office occupations aged 16 years old and older in the county. |
# | memp_sales | number | Percent of male civilians employed in sales and office occupations aged 16 years old and older in the county. |
# | femp_sales | number | Percent of female civilians employed in sales and office occupations aged 16 years old and older in the county. |
# | emp_n | number | Percent of civilians employed in natural resources, construction, and maintenance occupations aged 16 years old and older in the county. |
# | memp_n | number | Percent of male civilians employed in natural resources, construction, and maintenance occupations aged 16 years old and older in the county. |
# | femp_n | number | Percent of female civilians employed in natural resources, construction, and maintenance occupations aged 16 years old and older in the county. |
# | emp_p | number | Percent of civilians employed in production, transportation, and material moving occupations aged 16 years old and older in the county. |
# | memp_p | number | Percent of male civilians employed in production, transportation, and material moving occupations aged 16 years old and older in the county. |
# | femp_p | number | Percent of female civilians employed in production, transportation, and material moving occupations aged 16 years old and older in the county. |
# | mcsa | number | Weekly, full-time median price charged for Center-Based Care for those who are school age based on the results reported in the market rate survey report <br>for the county or the rate zone/cluster to which the county is assigned. |
# | mfccsa | number | Weekly, full-time median price charged for Family Childcare for those who are school age based on the results reported in the market rate survey report <br>for the county or the rate zone/cluster to which the county is assigned. |
# | mc_infant | number | Aggregated weekly, full-time median price charged for Center-based Care for infants (i.e. aged 0 through 23 months). |
# | mc_toddler | number | Aggregated weekly, full-time median price charged for Center-based Care for toddlers (i.e. aged 24 through 35 months). |
# | mc_preschool | number | Aggregated weekly, full-time median price charged for Center-based Care for preschoolers (i.e. aged 36 through 54 months). |
# | mfcc_infant | number | Aggregated weekly, full-time median price charged for Family Childcare for infants (i.e. aged 0 through 23 months). |
# | mfcc_toddler | number | Aggregated weekly, full-time median price charged for Family Childcare for toddlers (i.e. aged 24 through 35 months). |
# | mfcc_preschool | number | Aggregated weekly, full-time median price charged for Family Childcare for preschoolers (i.e. aged 36 through 54 months). |
#
# ### **counties.csv**
# | variable | class | description |
# | :--- | :--- | :--- |
# | county_fips_code | number | Four- or five-digit number that uniquely identifies the county in a state. <br>The first two digits (for five-digit numbers) or 1 digit (for four-digit numbers) refer to the FIPS code of the state to which the county belongs. |
# | county_name | character | The full name of the county. |
# | state_name | character | The full name of the state in which the county is found. |
# | state_abbreviation | character | The two-letter state abbreviation. |

# %% [markdown]
# # **Load Data**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

childcare_costs = pd.read_csv(
    '/content/drive/MyDrive/BA820_Unsupervised_Machine_Learning/project/childcare_costs.csv'
)

counties = pd.read_csv(
    '/content/drive/MyDrive/BA820_Unsupervised_Machine_Learning/project/counties.csv'
)

# %%
# check childcare_cost dataset
childcare_costs.info()
childcare_costs.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34567 entries, 0 to 34566
# Data columns (total 61 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   county_fips_code           34567 non-null  int64
#  1   study_year                 34567 non-null  int64
#  2   unr_16                     34567 non-null  float64
#  3   funr_16                    34567 non-null  float64
#  4   munr_16                    34567 non-null  float64
#  5   unr_20to64                 34567 non-null  float64
#  6   funr_20to64                34567 non-null  float64
#  7   munr_20to64                34567 non-null  float64
#  8   flfpr_20to64               34567 non-null  float64
#  9   flfpr_20to64_under6        34567 non-null  float64
#  10  flfpr_20to64_6to17         34567 non-null  float64
#  11  flfpr_20to64_under6_6to17  34567 non-null  float64
#  12  mlfpr_20to64               34567 non-null  float64
# ...

# %%
# check counties dataset
counties.info()
counties.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3144 entries, 0 to 3143
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   county_fips_code    3144 non-null   int64
#  1   county_name         3144 non-null   object
#  2   state_name          3144 non-null   object
#  3   state_abbreviation  3144 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 98.4+ KB
#    county_fips_code     county_name state_name state_abbreviation
# 0              1001  Autauga County    Alabama                 AL
# 1              1003  Baldwin County    Alabama                 AL
# 2              1005  Barbour County    Alabama                 AL
# 3              1007     Bibb County    Alabama                 AL
# 4              1009   Blount County    Alabama                 AL

# %%
# convert datatype
childcare_costs['county_fips_code'] = childcare_costs['county_fips_code'].astype(str)
counties['county_fips_code'] = counties['county_fips_code'].astype(str)

# merge data
merged_df = pd.merge(
    childcare_costs,
    counties,
    on='county_fips_code',
    how='inner',
    indicator=True
)

# %% [markdown]
# #**Merged Data EDA**

# %%
# check the result of inner join
merged_df['_merge'].value_counts()
# Out:
# _merge
# both          34567
# left_only         0
# right_only        0
# Name: count, dtype: int64

# %%
# check the shape of merged dataframe
merged_df.shape
# Out:
# (34567, 65)

# %%
# save merged data
merged_df.to_csv(
    '/content/drive/MyDrive/BA820_Unsupervised_Machine_Learning/project/childcare_cost_with_counties.csv',
    index=False
)

# %%
# check data info of merged data
merged_df.info()
merged_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34567 entries, 0 to 34566
# Data columns (total 65 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   county_fips_code           34567 non-null  object
#  1   study_year                 34567 non-null  int64
#  2   unr_16                     34567 non-null  float64
#  3   funr_16                    34567 non-null  float64
#  4   munr_16                    34567 non-null  float64
#  5   unr_20to64                 34567 non-null  float64
#  6   funr_20to64                34567 non-null  float64
#  7   munr_20to64                34567 non-null  float64
#  8   flfpr_20to64               34567 non-null  float64
#  9   flfpr_20to64_under6        34567 non-null  float64
#  10  flfpr_20to64_6to17         34567 non-null  float64
#  11  flfpr_20to64_under6_6to17  34567 non-null  float64
#  12  mlfpr_20to64               34567 non-null  float64
# ...

# %% [markdown]
# The merged dataset has 34,567 rows and 65 columns. The attributes: h_under6_single_m, h_6to17_single_m, mcsa, mfccsa, mc_infant, mc_toddler, mc_preschool, mfcc_infant, mfcc_toddler, mfcc_preschool all have some missing values.

# %%
# check statistical summary of merged data
merged_df.describe()
# Out:
#          study_year        unr_16      funr_16       munr_16    unr_20to64  \
# count  34567.000000  34567.000000  34567.00000  34567.000000  34567.000000
# mean    2012.999711      7.465902      7.02902      7.860291      6.900073
# std        3.162232      3.538619      3.56342      4.037657      3.446199
# min     2008.000000      0.000000      0.00000      0.000000      0.000000
# 25%     2010.000000      5.100000      4.64000      5.200000      4.600000
# 50%     2013.000000      7.050000      6.59000      7.390000      6.500000
# 75%     2016.000000      9.350000      8.88000      9.920000      8.700000
# max     2018.000000     36.110000     38.24000     39.740000     33.900000
#
#         funr_20to64   munr_20to64  flfpr_20to64  flfpr_20to64_under6  \
# count  34567.000000  34567.000000  34567.000000         34567.000000
# mean       6.482007      7.275457     70.086125            68.821409
# std        3.477956      3.990758      7.696499            11.758088
# ...

# %% [markdown]
# # **Milestone 1 - EDA**

# %% [markdown]
# ## **Gender Earning Gaps**

# %%
merged_df['earnings_gap'] = merged_df['fme_2018'] - merged_df['mme_2018']
merged_df['earnings_gap'].hist(bins=40, figsize=(6,4))
# Out:
# <Axes: >

# %% [markdown]
# There's an inequality in earnings distribution in 2018, with women earning less than men since the distribution is not centered at zero but towards large negative values.

# %% [markdown]
# ## **Labor Force Comparison**

# %%
merged_df['lfp_gap'] = merged_df['flfpr_20to64'] - merged_df['mlfpr_20to64']
merged_df['lfp_gap'].hist(bins=40, figsize=(6,4))
# Out:
# <Axes: >

# %%
merged_df['lfp_gap'].describe()
# Out:
# count    34567.000000
# mean        -8.551689
# std          9.075836
# min        -50.000000
# 25%        -13.200000
# 50%         -9.400000
# 75%         -5.700000
# max         60.400000
# Name: lfp_gap, dtype: float64

# %% [markdown]
# Overall, the average labor force participation rate gap between women and men aged 20 to 64 is approximately −8.55, indicating that women’s employment rate is lower than men’s.

# %%
merged_df[
    ['flfpr_20to64', 'flfpr_20to64_under6', 'flfpr_20to64_6to17']
].boxplot(figsize=(6,4))
# Out:
# <Axes: >

# %% [markdown]
# Labor force participation of the female population ages 20–64, ages 20–64 with children under 6, and ages 20–64 with children ages 6–17.
# The boxplots above indicate that from the three attributes, women ages 20-64 with children under 6 have the most outliers where there is very weak or no participation from them in the workforce.

# %% [markdown]
# ## **Racial Demographics**

# %%
import pandas as pd
import matplotlib.pyplot as plt

demo_cols = [
    'one_race_w',
    'one_race_b',
    'one_race_i',
    'one_race_a',
    'one_race_h',
    'one_race_other',
    'two_races',
    'hispanic'
]

demo_means = merged_df[demo_cols].mean()

# %%
plt.figure(figsize=(10,6))
demo_means.plot(kind='bar')

plt.title('Average Demographic Composition Across Counties')
plt.ylabel('Percentage of Population')
plt.xlabel('Demographic Group')
plt.xticks(rotation=45, ha='right')
plt.ylim(0, 100)

plt.tight_layout()
plt.show()

# %% [markdown]
# Over 80% of the population identifies as belonging to a single race, specifically White or Caucasian, making it the dominant racial group in this dataset.

# %% [markdown]
# ## **Houeshold Composition**

# %%
import matplotlib.pyplot as plt
import pandas as pd

household_cols = [
    'h_under6_both_work',
    'h_under6_f_work',
    'h_under6_m_work',
    'h_under6_single_m',
    'h_6to17_both_work',
    'h_6to17_fwork',
    'h_6to17_mwork',
    'h_6to17_single_m'
]

household_totals = merged_df[household_cols].sum()

# %%
household_df = pd.DataFrame({
    'Under 6': [
        household_totals['h_under6_both_work'],
        household_totals['h_under6_f_work'],
        household_totals['h_under6_m_work'],
        household_totals['h_under6_single_m']
    ],
    'Ages 6–17': [
        household_totals['h_6to17_both_work'],
        household_totals['h_6to17_fwork'],
        household_totals['h_6to17_mwork'],
        household_totals['h_6to17_single_m']
    ]
}, index=[
    'Both Parents Working',
    'Father Only Working',
    'Mother Only Working',
    'Single Mother'
])

household_df.plot(
    kind='bar',
    stacked=True,
    figsize=(10,6)
)

plt.title('Household Composition by Child Age Group')
plt.ylabel('Number of Households')
plt.xlabel('Household Work Structure')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Child Age Group')
plt.tight_layout()
plt.show()

# %% [markdown]
# Households with children under six are less likely to have both parents working and more likely to rely on single-earner or single-mother arrangements, while households with children aged 6–17 are predominantly dual-earner, reflecting reduced childcare constraints as children reach school age. It is also important to note that father-only working households far outnumber mother-only working households in both age groups, highlighting persistent gender asymmetries in caregiving and labor force participation.

# %%
import matplotlib.pyplot as plt

# Create LFPR gap
merged_df['lfpr_gap'] = (
    merged_df['flfpr_20to64'] - merged_df['flfpr_20to64_under6']
)

plt.figure(figsize=(8,6))

sc = plt.scatter(
    merged_df['emp_m'],
    merged_df['emp_service'],
    c=merged_df['lfpr_gap'],
    cmap = 'coolwarm',
    alpha=0.7
)

plt.xlabel('Management / Professional Occupations (%)')
plt.ylabel('Service Occupations (%)')
plt.title('Employment Structure and LFPR Gap for Parents with Children Under 6')

plt.colorbar(sc, label='LFPR Gap')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# The plot above depicts the Labor Force Participation Rate Gap, where warmer colors indicate a larger gap and cooler colors showing a smaller gap. We can see that there is a greater constrain and larger LFPR gap for parents to stay in the larbor force in service occupations. In contrast, counties with a greater share of management and professional occupations generally show smaller participation gaps, suggesting that job flexibility, wages, and workplace supports may mitigate childcare-related labor market penalties.

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

merged_df['lfpr_gap'] = (
    merged_df['flfpr_20to64'] - merged_df['flfpr_20to64_under6']
)

merged_df['county_fips_code'] = (
    merged_df['county_fips_code'].astype(str).str.zfill(5)
)

counties = gpd.read_file(
    "https://www2.census.gov/geo/tiger/GENZ2021/shp/cb_2021_us_county_500k.zip"
)

counties['GEOID'] = counties['GEOID'].astype(str)

map_df = counties.merge(
    merged_df,
    left_on='GEOID',
    right_on='county_fips_code',
    how='left'
)

contiguous = map_df[
    ~map_df['STATEFP'].isin(['02', '15', '60', '66', '69', '72', '78'])
]

fig, ax = plt.subplots(1, 1, figsize=(14,10))

vmax = max(
    abs(contiguous['lfpr_gap'].min()),
    abs(contiguous['lfpr_gap'].max())
)

contiguous.plot(
    column='lfpr_gap',
    cmap='coolwarm',
    vmin=-vmax,
    vmax=vmax,
    linewidth=0.05,
    edgecolor='black',
    legend=True,
    ax=ax
)

ax.set_title(
    'Labor Force Participation Gap for Parents with Children Under 6\n(Contiguous United States)',
    fontsize=14
)
ax.axis('off')

plt.show()

# %% [markdown]
# The map reveals regional clustering in labor force participation gaps for parents with children under six. Larger gaps are more prevalent across parts of the Midwest and South, while smaller gaps are more common in Northern regions, along the West Coast, and in major metropolitan areas. This spatial pattern suggests that local labor market conditions and institutional supports play an important role in shaping parental labor force participation outcomes.

# %%
import matplotlib.pyplot as plt

cols = [
    'mc_infant', 'mfcc_infant',
    'mc_toddler', 'mfcc_toddler',
    'mc_preschool', 'mfcc_preschool'
]

merged_df[cols].boxplot(figsize=(12,6), rot=45)

plt.title('Weekly Childcare Costs by Setting and Child Age')
plt.ylabel('Weekly Median Price ($)')
plt.tight_layout()
plt.show()

# %% [markdown]
# The boxplots above are comparing the weekly childcare cost distribution. The presence of high outliers indicates that childcare costs can be exceptionally high in certain counties(metropolitan places), particularly for infants and center-based care. While most counties fall within a more moderate cost range, this variation highlights substantial geographic inequality in childcare affordability, which may contribute to uneven labor force participation outcomes among parents with young children.

# %% [markdown]
# # **Milestone 2 - Theme 4: Policy Interventions**

# %% [markdown]
# ## Further EDA

# %% [markdown]
# ### Affordability Ratio

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# calculate the propotion of childcare costs to income
# define variable groups
age_groups = ['infant', 'toddler', 'preschool', 'sa']
care_types = ['mc', 'mfcc']
care_type_name = {'mc': 'center', 'mfcc': 'family'}

# create a subplot with 2 rows x 4 columns
fig, axes = plt.subplots(2, 4, figsize=(22, 10), sharex=True)
fig.suptitle('Affordability Ratios Across All Age Groups', fontsize=18)

for i, c_type in enumerate(care_types):
  for j, age in enumerate(age_groups):

    if age == 'sa':
      col_name = f'{c_type}{age}'
    else:
      col_name = f'{c_type}_{age}'

    ratio_col = f'{col_name}_ratio'  # for creating new columns

    # convert childcare cost to yearly price and divided by yearly income
    merged_df[ratio_col] = (merged_df[col_name] * 52) / merged_df['mhi_2018']

    # plot histogram
    sns.histplot(merged_df[ratio_col], kde=True, ax=axes[i, j], color='skyblue' if c_type=='mc' else 'orange')
    axes[i, j].set_title(f'{care_type_name[c_type]} - {age}')
    axes[i, j].set_xlabel('Affordability Ratio')
    axes[i, j].set_ylabel('Number of Counties')

    # mark the 10% affordability threshold
    axes[i, j].axvline(0.1, color='red', linestyle='--')

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %% [markdown]
# These histograms visualize the affordability ratio of counties across four child age groups (infant, toddler, preschool, and school age) and two care types (Center-Based care and Family Childcare). The red dashed line represents the **10% affordability threshold** traditionally defined by the US Department of Health and Human Services (HHS, https://www.federalregister.gov/documents/2016/09/30/2016-22986/child-care-and-development-fund-ccdf-program). Across all eight categories, the area to the right of the red line represents a substantial proportion of counties where childcare is considered unaffordable.
#
# Center-Based Care distributions are noticeably shifted further to the right compared to Family Childcare in child under 6 (infant, toddler, and pre-school) groups, indicating that center-based settings impose a substantially higher financial burden on median-income households.
#
# As children transition from infant to school age status, the peak of the distribution moves slightly to the left, suggesting a decrease in cost pressure. However, the long tail persists, highlighting that for many counties, childcare remains a crisis regardless of the child's age.

# %% [markdown]
# ### Childcare Type Dominance

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# define data pairs
pairs = {'Infant': ('mc_infant', 'mfcc_infant'),
      'Toddler': ('mc_toddler', 'mfcc_toddler'),
      'Preschool': ('mc_preschool', 'mfcc_preschool'),
      'School Age': ('mcsa', 'mfccsa')}

# plot scatter plot
fig, axes = plt.subplots(2, 2, figsize=(14, 12), constrained_layout=True)
axes = axes.ravel()
vmin, vmax = merged_df['flfpr_20to64'].min(), merged_df['flfpr_20to64'].max()

for ax, (title, (xcol, ycol)) in zip(axes, pairs.items()):
    sc = ax.scatter(merged_df[xcol], merged_df[ycol], c=merged_df['flfpr_20to64'], vmin=vmin, vmax=vmax, alpha=0.75)

    # mark y=x line
    ax.plot([merged_df[xcol].min(), merged_df[xcol].max()], [merged_df[ycol].min(), merged_df[ycol].max()], "--", linewidth=1)

    ax.set_title(title)
    ax.set_xlabel(f"Center-Based care price ({xcol})")
    ax.set_ylabel(f"Family Childcare price ({ycol})")

# set colorbar
cbar = fig.colorbar(sc, ax=axes, location="right", shrink=0.85, pad=0.02)
cbar.set_label("Female Labor Force Participation Rate (flfpr_20to64)")
plt.show()

# %% [markdown]
# The scatter plots indicate that weekly prices for Center-Based care generally range from approximately \$50 to \$300, while Family Childcare prices mostly fall between \$50 and \$200.
#
# For children under 6 (infant, toddler, and preschool groups), Center-Based care is more expensive than Family Childcare in the vast majority of counties, especially in the infant group. This pattern suggests that Center-Based care is the dominant childcare type in most counties for younger children. In contrast, for school-age children, the prices of the 2 care types are more balanced, and in some counties, Family Childcare is even more expensive than Center-Based care.
#
# Notably, across all age groups, counties with lower childcare prices (approximately \$50–\$150) tend to have lower female labor force participation rates, whereas counties with mid- to high-priced childcare (above \$150) generally exhibit higher female labor force participation. This pattern suggests that heavier childcare cost burdens may be associated with higher levels of female labor market participation.

# %% [markdown]
# ### Affordability Deviation From Norms

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# define variable groups (the same as affordability ratio analysis)
age_groups = ['infant', 'toddler', 'preschool', 'sa']
care_types = ['mc', 'mfcc']
ratio_cols = ['mc_infant_ratio', 'mfcc_infant_ratio',
        'mc_toddler_ratio', 'mfcc_toddler_ratio',
        'mc_preschool_ratio', 'mfcc_preschool_ratio',
        'mcsa_ratio', 'mfccsa_ratio']

# calculate the average affordability ratio for each county across years
county_avg = merged_df.groupby(['county_name', 'state_name'])[ratio_cols].mean().reset_index()

# calculate the z-score of each county in its state
def zscore(x):
    return (x - x.mean()) / x.std()

z_cols = []
for col in ratio_cols:
    z_col = f'z_{col}'
    county_avg[z_col] = county_avg.groupby('state_name')[col].transform(zscore)
    z_cols.append(z_col)

# find the most anomalous counties by the max |z| across columns
county_avg['max_abs_z'] = county_avg[z_cols].abs().max(axis=1)  # pick the max |z| for each z_col

top_n = 20  # pick the top 20 counties
top_df = county_avg.nlargest(top_n, 'max_abs_z').copy()

# plot heatmap: rows = counties, columns = ratios
top_df['county_state'] = top_df['county_name'] + ', ' + top_df['state_name']
heatmap_data = top_df.set_index('county_state')[z_cols]

plt.figure(figsize=(14, 10))
sns.heatmap(heatmap_data, cmap='coolwarm', center=0, linewidths=0.3, linecolor='white')
plt.title(f'Deviation from State Norms (Z-scores) — Top {top_n} Most Anomalous Counties')
plt.xlabel('Care Type & Age Group (Z-score of Affordability Ratio within State)')
plt.ylabel('County, State')
plt.tight_layout()
plt.show()

# display the top 20 anomalies table
display_cols = ['county_name', 'state_name', 'max_abs_z'] + z_cols
top_anomalies = top_df[display_cols]
print(f"Top {top_n} Most Anomalous Counties (max absolute z-score across all ratios):")
print(top_anomalies.head(20))
# Out:
# Top 20 Most Anomalous Counties (max absolute z-score across all ratios):
#               county_name      state_name  max_abs_z  z_mc_infant_ratio  \
# 277          Bronx County        New York   6.129855           6.129855
# 281         Brooks County           Texas   5.553741           5.553741
# 1927     Milwaukee County       Wisconsin   4.969194           4.875144
# 2376        Ramsey County       Minnesota   4.950445           4.950445
# 2245  Philadelphia County    Pennsylvania   4.932618           4.872747
# 89            Ashe County  North Carolina   4.526471           0.236736
# 2180        Owyhee County           Idaho   4.389538           3.461970
# 741         DeKalb County        Illinois   4.351225           1.920081
# 629           Cook County        Illinois   4.241594           1.830132
# 3111     Wyandotte County          Kansas   4.029236           4.029236
# 34       Alexander County        Illinois   3.997826           3.422934
# ...

# %% [markdown]
# The heatmap shows county-level deviations from state affordability norms using z-scores calculated from multi-year average affordability ratios, where positive values indicate higher childcare cost burdens relative to the state average.
#
# Several large urban counties, such as Bronx County (NY), Philadelphia County (PA), Milwaukee County (WI), and Cook County (IL), exhibit consistently high positive z-scores across nearly all age groups and care types, suggesting a structurally elevated childcare affordability burden rather than age-specific or care-type-specific anomalies.
#
# In contrast, some counties show more heterogeneous patterns, with deviations concentrated in particular age groups or care types, indicating localized mismatches rather than systemic stress.
#
# Notably, Williamson County (TN) stands out with uniformly negative z-scores across all categories, reflecting a structurally lower childcare burden relative to its state norm and serving as a potential benchmark case.

# %% [markdown]
# ### Correlation Analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# create feature: gender gap in labor force participation
merged_df['lfp_gap'] = merged_df['flfpr_20to64'] - merged_df['mlfpr_20to64']  # has been created in M1 EDA

# define observed variances
analysis_vars = [
    'mc_infant_ratio', 'mfcc_infant_ratio',
    'mc_toddler_ratio', 'mfcc_toddler_ratio',
    'mc_preschool_ratio', 'mfcc_preschool_ratio',
    'flfpr_20to64', 'lfp_gap', 'pr_f'
]

# plot heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(merged_df[analysis_vars].corr(), annot=True, cmap='coolwarm', center=0, fmt=".2f")
plt.title('Correlation Matrix: Childcare Stress vs. Labor Outcomes')
plt.show()

# %% [markdown]
# This correlation analysis aims to identify relationships among columns and use the heatmap results to inform dimension selection in downstream unsupervised machine learning to avoid redundancy.
#
# The heatmap indicates strong positive correlations among childcare affordability ratios across age groups and childcare types. Based on prior EDA results showing higher affordability ratios for infants Center-Based care, **mc_infant_ratio** was chosen as representative for childcare costs.
#
# In addition, for the labor force participation dimension, I selected the gender gap in labor force participation (**lfp_gap**) and the female labor force participation rate (**flfpr_20to64**). These measures capture both gender disparities in labor participation at the county level and the relationship between childcare costs and women’s labor force participation.
#
# I opted to use the poverty rate (**pr_f**) instead of median household income (mhi_2018) as a clustering feature to avoid the causality with affordability ratios.

# %% [markdown]
# ## Theme 4: Policy Interventions

# %% [markdown]
# ### **(1) Can we use unsupervised clustering and anomaly detection to identify latent childcare crisis profiles in counties where costs, income, and labor participation exhibit extreme mismatch, and how do these clusters differ from regional economic norms?**

# %% [markdown]
# ##### Data Pre-processing

# %%
import numpy as np
import pandas as pd

# representative
rep_cols = [
    'mc_infant_ratio',
    'lfp_gap',
    'flfpr_20to64',
    'pr_f'
]

# prepare dataframe for clustering
id_cols = ['county_fips_code', 'county_name', 'state_name']
df_cluster = (merged_df[id_cols + rep_cols]
        .groupby(id_cols, as_index=False)[rep_cols]
        .mean())  # take the mean of each representative

print(f'df_cluster shape: {df_cluster.shape}')
df_cluster.info()
df_cluster.head()
# Out:
# df_cluster shape: (3144, 7)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3144 entries, 0 to 3143
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   county_fips_code  3144 non-null   object
#  1   county_name       3144 non-null   object
#  2   state_name        3144 non-null   object
#  3   mc_infant_ratio   2904 non-null   float64
#  4   lfp_gap           3144 non-null   float64
#  5   flfpr_20to64      3144 non-null   float64
#  6   pr_f              3144 non-null   float64
# dtypes: float64(4), object(3)
# memory usage: 172.1+ KB
#   county_fips_code     county_name state_name  mc_infant_ratio    lfp_gap  \
# 0            01001  Autauga County    Alabama         0.097619 -14.700000
# 1            01003  Baldwin County    Alabama         0.103471 -13.745455
# 2            01005  Barbour County    Alabama         0.122622   9.063636
# ...

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

# feature matrix
X = df_cluster[rep_cols].copy()

# build a pre-processing pipeline
prep_pipeline = Pipeline(steps=[('imputer', SimpleImputer(strategy='median')),  # fill missing values with median
              ('scaler', StandardScaler())])  # normalize: mean = 0, sd = 1

# transform data
Xs_std = prep_pipeline.fit_transform(X)

print(f'Xs_std shape: {Xs_std.shape}')
# Out:
# Xs_std shape: (3144, 4)

# %% [markdown]
# ##### K-means Clustering

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

def kmeans_grid(Xs, k_list=range(2, 11), random_state=42):  # try k = 2 to 10
    rows = []
    labels_dict = {}

    for k in k_list:
        km = KMeans(n_clusters=k, random_state=random_state)
        labels = km.fit_predict(Xs)  # fit data and predict
        sse = km.inertia_  # SSE: sum of squared errors to cluster centers
        sil = silhouette_score(Xs, labels)  # silhouette score
        rows.append({'K': k, 'SSE': sse, 'silhouette_score': silhouette_score(Xs, labels)})
        labels_dict[k] = labels
    return pd.DataFrame(rows), labels_dict

# run on the scaler
res_std, labels_dict = kmeans_grid(Xs_std, range(2, 11))

display(res_std)
# Out:
#     K          SSE  silhouette_score
# 0   2  9123.774359          0.288488
# 1   3  7599.810812          0.302539
# 2   4  6219.109782          0.299516
# 3   5  5300.558436          0.269582
# 4   6  4811.405292          0.228595
# 5   7  4464.842606          0.213623
# 6   8  4146.966077          0.217296
# 7   9  3885.966831          0.218349
# 8  10  3698.514762          0.214607

# %%
# plot the Elbow and Silhouette figures

import matplotlib.pyplot as plt

# Elbow plot (SSE)
plt.figure(figsize=(6, 4))
plt.plot(res_std['K'], res_std['SSE'], marker='o')
plt.title('Elbow (SSE)')
plt.xlabel('K')
plt.ylabel('SSE (inertia)')
plt.show()

# Silhouette plot
plt.figure(figsize=(6, 4))
plt.plot(res_std['K'], res_std['silhouette_score'], marker='o')
plt.title('Silhouette')
plt.xlabel('K')
plt.ylabel('Silhouette score')
plt.show()

# %% [markdown]
# Using the K-means clustering method, I examined K values ranging from 2 to 10. The SSE smoothly declines along with increasing K. This transition suggests that there are no naturally rigid boundaries between clusters.
#
# The highest silhouette score is at K=3, followed by K=4. When K≥5, the scores decrease significantly, indicating that additional clusters lead to poorer separation and more overlap. Although silhouette score is also high at K=2, it results in overly coarse clusters that obscure important heterogeneity in childcare affordability and female labor force outcomes.
#
# Overall, these results support using K=2 as a simple baseline, while K=4 (with lower SSE than K=3, and a relatively high silhouette score) provides a more nuanced yet still well-separated typology for interpretation.

# %%
# output cluster profile

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

rep_cols = ['mc_infant_ratio', 'lfp_gap', 'flfpr_20to64', 'pr_f']
k_to_plot = [2, 4]

for k in k_to_plot:
    labels = labels_dict[k]
    df_tmp = df_cluster.copy()  # temporary df for saving cluster labels
    df_tmp[f'cluster_k{k}'] = labels

    sizes = df_tmp[f'cluster_k{k}'].value_counts().sort_index()  # cluster size
    raw_profile = df_tmp.groupby(f'cluster_k{k}')[rep_cols].mean()  # take the mean for each feature

    # standardize: convert values to z-score (more comparable)
    df_std = df_tmp.copy()
    for c in rep_cols:
        df_std[c] = (df_std[c] - df_std[c].mean()) / df_std[c].std()

    # take the mean after standardization
    std_profile = df_std.groupby(f'cluster_k{k}')[rep_cols].mean()

    # set the mean as the threshold: > threshold (High); < threshold (Low)
    th_burden = raw_profile['mc_infant_ratio'].mean()
    th_flfp = raw_profile['flfpr_20to64'].mean()
    th_gap = raw_profile['lfp_gap'].mean()
    th_pov = raw_profile['pr_f'].mean()

    # name clusters
    cluster_names = {}
    for cl in raw_profile.index:
        burden_tag = 'High-burden' if raw_profile.loc[cl, 'mc_infant_ratio'] >= th_burden else 'Low-burden'
        flfp_tag = 'High-flfp' if raw_profile.loc[cl, 'flfpr_20to64'] >= th_flfp else 'Low-flfp'
        gap_tag = 'High-gap' if raw_profile.loc[cl, 'lfp_gap'] >= th_gap else 'Low-gap'
        pov_tag = 'High-poverty' if raw_profile.loc[cl, 'pr_f'] >= th_pov else 'Low-poverty'
        cluster_names[cl] = f'{burden_tag}, {flfp_tag}, {gap_tag}, {pov_tag})'

    # set rows' names and plot heatmap
    new_index = []
    for cl in std_profile.index:
        new_index.append(f'Cluster {cl} (n={sizes.loc[cl]})\n{cluster_names[cl]}')
    std_profile.index = new_index

    plt.figure(figsize=(10, 3 + 0.6 * len(std_profile)))
    sns.heatmap(std_profile, cmap='coolwarm', center=0, annot=True, fmt='.2f')
    plt.title(f'Cluster Profile Heatmap (standardized) — K={k}')
    plt.xlabel('Features (standardized)')
    plt.tight_layout()
    plt.show()

    # output raw means table
    raw_out = raw_profile.copy().round(2)
    raw_out.insert(0, 'cluster_size', sizes.values)
    raw_out.insert(1, 'cluster_name', [cluster_names[cl] for cl in raw_out.index])

    print(f'\n===== K = {k} : Cluster Summary (raw means) =====')
    display(raw_out)
# Out:
# ===== K = 2 : Cluster Summary (raw means) =====
#             cluster_size                                    cluster_name  \
# cluster_k2
# 0                   1307  High-burden, Low-flfp, High-gap, High-poverty)
# 1                   1837    Low-burden, High-flfp, Low-gap, Low-poverty)
#
#             mc_infant_ratio  lfp_gap  flfpr_20to64   pr_f
# cluster_k2
# 0                      0.16    -7.86         63.80  16.36
# 1                      0.15    -9.04         74.57   8.45
# ===== K = 4 : Cluster Summary (raw means) =====
#             cluster_size                                   cluster_name  \
# cluster_k4
# 0                    192  Low-burden, Low-flfp, High-gap, High-poverty)
# 1                   1451   Low-burden, High-flfp, Low-gap, Low-poverty)
# 2                   1070   Low-burden, Low-flfp, Low-gap, High-poverty)
# 3                    431  High-burden, High-flfp, Low-gap, Low-poverty)
#
#             mc_infant_ratio  lfp_gap  flfpr_20to64   pr_f
# cluster_k4
# ...

# %% [markdown]
# For K=2, counties separate into two broad groups: one with higher infant childcare burden and poverty combined with lower female labor force participation, and another with lower burden and poverty and higher female labor force participation. This indicates a clear structural divide between high-stress and more advantaged childcare–labor market contexts.
#
# For K=4, the clustering reveals more nuanced patterns. Compared to the corresponding average of the entire data, the results show that there is a large low-burden, high-participation, low-poverty group. In addition, there are counties with low childcare burden but low female labor participation and high poverty, suggesting that affordability alone does not guarantee labor market engagement. A distinct small cluster shows an extreme labor force participation gap, while another smaller cluster represents high childcare burden but relatively strong female labor participation, consistent with high-cost labor markets where childcare is expensive yet employment remains high.

# %% [markdown]
# ##### Hierarchical Clustering

# %%
from scipy.cluster.hierarchy import linkage, fcluster, dendrogram
import matplotlib.pyplot as plt
import pandas as pd

k_final = 4   # final choice of K

Z_ward = linkage(Xs_std, method='ward')  # build linkage matrix: try ward linkage
Z_avg = linkage(Xs_std, method='average')  # build linkage matrix: try average linkage

# plot dendrogram (Z_ward)
plt.figure(figsize=(14, 5))
dendrogram(Z_ward, truncate_mode='lastp', p=30, show_leaf_counts=True)  # only display the last part, and up to 30 clusters
cut_height = Z_ward[-(k_final-1), 2]  # mark the line with K clusters
plt.axhline(y=cut_height, c='red', linestyle='--', label=f'Cut for k={k_final}')
plt.legend()
plt.title(f'Hierarchical Dendrogram (ward linkage with cut at k = {k_final})')
plt.xlabel('Cluster (truncated)')
plt.ylabel('Distance')
plt.show()

# plot dendrogram (Z_avg)
plt.figure(figsize=(14, 5))
dendrogram(Z_avg, truncate_mode='lastp', p=30, show_leaf_counts=True)  # only display the last part, and up to 30 clusters
cut_height = Z_avg[-(k_final-1), 2]  # mark the line with K clusters
plt.axhline(y=cut_height, c='red', linestyle='--', label=f'Cut for k={k_final}')
plt.legend()
plt.title(f'Hierarchical Dendrogram (average linkage with cut at k = {k_final})')
plt.xlabel('Cluster (truncated)')
plt.ylabel('Distance')
plt.show()

# %% [markdown]
# The dendrograms visualize hierarchical clustering results using Ward and average linkage with a cut at K=4.
#
# Under Ward linkage, several clear vertical jumps appear before the cut line, indicating relatively well-separated clusters with strong within-cluster similarity. This suggests the presence of distinct county profiles characterized by different levels of childcare affordability stress and female labor force participation.
#
# In contrast, average linkage shows a poor separation between clusters. While a four-cluster solution is still feasible, the cluster boundaries are less distinct.

# %% [markdown]
# ##### Compare K-means & Hierarchical Clustering

# %%
from sklearn.cluster import KMeans

# create a dataframe to store clustering labels
z_df = df_cluster[id_cols + rep_cols].copy()

# cut the hierarchical tree into k_final clusters
z_df['cluster_hier_ward'] = fcluster(Z_ward, t=k_final, criterion='maxclust') - 1  # index starts from 0
z_df['cluster_hier_avg'] = fcluster(Z_avg, t=k_final, criterion='maxclust') - 1  # index starts from 0

# fit K-means to generate baseline labels
km = KMeans(n_clusters=k_final, random_state=42)
z_df['cluster_kmeans'] = km.fit_predict(Xs_std)

# compare consistency between K-means vs Hierarchical
print('Crosstab: K-means vs Hierarchical (Ward)')
display(pd.crosstab(z_df['cluster_kmeans'], z_df['cluster_hier_ward']))

print('Crosstab: K-means vs Hierarchical (Average)')
display(pd.crosstab(z_df['cluster_kmeans'], z_df['cluster_hier_avg']))
# Out:
# Crosstab: K-means vs Hierarchical (Ward)
# cluster_hier_ward    0     1    2    3
# cluster_kmeans
# 0                    4     0    0  188
# 1                   69  1325    7   50
# 2                  818   117   51   84
# 3                    0   126  284   21
# Crosstab: K-means vs Hierarchical (Average)
# cluster_hier_avg  0     1   2  3
# cluster_kmeans
# 0                 0   189   3  0
# 1                 0  1451   0  0
# 2                 0  1052  18  0
# 3                 4   426   0  1

# %% [markdown]
# Based on the cross-table, the clustering results from K-means and Ward’s hierarchical method show partial alignment rather than a one-to-one correspondence. For example, K-means cluster 1 largely maps to Ward cluster 1 (1,325 observations), while K-means clusters 2 and 3 are distributed across multiple Ward clusters, indicating that the two methods define cluster boundaries differently for some counties.
#
# In contrast, the Average linkage method assigns the majority of counties to a single cluster (cluster 1), resulting in an unclear clustering structure with limited discriminatory power.

# %% [markdown]
# ### **(2) What are the underlying association patterns between the dominant childcare provider type, Center-Based Care vs. Family Childcare, and parental labor force participation, and can these patterns reveal where current infrastructure fails to support flexible work schedules?**

# %% [markdown]
# ##### Data Pre-processing

# %%
import numpy as np
import pandas as pd

# calculate county-level multi-year averages
id_cols = ['county_fips_code', 'county_name', 'state_name']

base_cols = [
    'mc_infant_ratio',
    'mfcc_infant_ratio',  # for calculating provider ratios and defining dominance
    'lfp_gap',
    'flfpr_20to64',
    'pr_f'
]

df_q2 = (merged_df[id_cols + ['study_year'] + base_cols]
      .groupby(id_cols, as_index=False)[base_cols]
      .mean()
)

# Screate provider dominance indicators
# provider_advantage > 0: Family Childcare burden higher than Center-Based care (Family Childcare less affordable)
# provider_advantage < 0: Center-Based care burden higher than Family Childcare (Center-Based care less affordable)
df_q2['provider_advantage'] = df_q2['mfcc_infant_ratio'] - df_q2['mc_infant_ratio']

print(f'df_q2 shape: {df_q2.shape}')
display(df_q2.head())
# Out:
# df_q2 shape: (3144, 9)
#   county_fips_code     county_name state_name  mc_infant_ratio  \
# 0            01001  Autauga County    Alabama         0.097619
# 1            01003  Baldwin County    Alabama         0.103471
# 2            01005  Barbour County    Alabama         0.122622
# 3            01007     Bibb County    Alabama         0.116678
# 4            01009   Blount County    Alabama         0.144870
#
#    mfcc_infant_ratio    lfp_gap  flfpr_20to64       pr_f  provider_advantage
# 0           0.089395 -14.700000     69.418182   8.845455           -0.008224
# 1           0.098904 -13.745455     68.509091   9.054545           -0.004567
# 2           0.110773   9.063636     64.127273  20.181818           -0.011849
# 3           0.096276  -5.209091     61.000000  11.581818           -0.020402
# 4           0.110279 -16.418182     60.900000  10.836364           -0.034590

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

# define representative variables
feature_cols = [
    'mc_infant_ratio',
    'provider_advantage',  # relative provider dominance (Family Childcare vs Center-Based care)
    'lfp_gap',
    'flfpr_20to64',
    'pr_f'
]

X = df_q2[feature_cols].copy()

# build a pre-processing pipeline
prep = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])
Xs = prep.fit_transform(X)

# %% [markdown]
# ##### K-means Clustering

# %%
from sklearn.cluster import KMeans, AgglomerativeClustering
from sklearn.metrics import silhouette_score

k_list = range(2, 11)  # try K = 2 to 10
rows = []
labels_by_k = {}

for k in k_list:
    km = KMeans(n_clusters=k, random_state=42)
    labels = km.fit_predict(Xs)

    rows.append({
        'K': k,
        'SSE': km.inertia_,
        'silhouette': silhouette_score(Xs, labels)
    })
    labels_by_k[k] = labels

res_k = pd.DataFrame(rows)
display(res_k)
# Out:
#     K           SSE  silhouette
# 0   2  12055.767022    0.247184
# 1   3   9348.006287    0.270600
# 2   4   7850.105229    0.287497
# 3   5   6875.443780    0.233983
# 4   6   6115.794343    0.221444
# 5   7   5644.760309    0.214083
# 6   8   5356.159387    0.191131
# 7   9   5048.950796    0.200227
# 8  10   4854.205173    0.196040

# %%
import matplotlib.pyplot as plt

# Elbow plot (SSE)
plt.figure(figsize=(6, 4))
plt.plot(res_k['K'], res_k['SSE'], marker='o')
plt.title('Elbow Plot (SSE)')
plt.xlabel('K')
plt.ylabel('SSE (inertia)')
plt.show()

# Silhouette plot
plt.figure(figsize=(6, 4))
plt.plot(res_k['K'], res_k['silhouette'], marker='o')
plt.title('Silhouette')
plt.xlabel('K')
plt.ylabel('Silhouette Score')
plt.show()

# %% [markdown]
# In the Elbow (SSE) plot, SSE decreases most rapidly before K=4, then levels off, indicating that around 4 clusters are sufficient to capture the main structure.
#
# The Silhouette plot also reaches its highest value at K=4, representing the best intra-cluster similarity and inter-cluster difference at this point.
#
# Combining these two indicators, K=4 is a more reasonable and interpretable cluster number, which can be used to further analyze the different patterns between 'Center-Based care vs. Family Childcare dominance' and the Labor Force Participation Rate (LFPR), and to pinpoint counties and cities that may lack flexible care support.

# %%
# output cluster profile

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

k_final = 4
df_q2['cluster_kmeans'] = labels_by_k[k_final]

print('K-means cluster sizes (k=4):')
display(df_q2['cluster_kmeans'].value_counts().sort_index())  # cluster size

# take the mean for each feature
profile_raw = (df_q2.groupby('cluster_kmeans')[feature_cols].mean().round(2))
print('Cluster profile (raw means):')
display(profile_raw)

# standardize: convert values to z-score (more comparable)
df_std = df_q2.copy()
for col in feature_cols:
    df_std[col] = (df_std[col] - df_std[col].mean()) / df_std[col].std(ddof=0)

profile_std = (df_std.groupby('cluster_kmeans')[feature_cols].mean().round(2))  # take the mean after standardization
print('Cluster profile (standardized means):')
display(profile_std)

# plot heatmap
plt.figure(figsize=(10, 4))
sns.heatmap(profile_std, annot=True, fmt='.2f', center=0, cmap='coolwarm')
plt.title('K-means Cluster Profiles (standardized means, k=4)')
plt.xlabel('Features')
plt.ylabel('Cluster')
plt.show()
# Out:
# K-means cluster sizes (k=4):
# cluster_kmeans
# 0     190
# 1     366
# 2    1120
# 3    1468
# Name: count, dtype: int64
# Cluster profile (raw means):
#                 mc_infant_ratio  provider_advantage  lfp_gap  flfpr_20to64  \
# cluster_kmeans
# 0                          0.15               -0.03    14.97         67.28
# 1                          0.22               -0.07    -7.72         71.82
# 2                          0.15               -0.02   -11.55         63.45
# 3                          0.14               -0.03    -9.52         75.08
#
#                  pr_f
# cluster_kmeans
# 0               14.99
# 1               10.70
# 2               16.09
# 3                8.26
# Cluster profile (standardized means):
#                 mc_infant_ratio  provider_advantage  lfp_gap  flfpr_20to64  \
# cluster_kmeans
# 0                         -0.00                0.33     2.81         -0.39
# 1                          1.75               -1.88     0.10          0.24
# ...

# %% [markdown]
# The clustering reveals meaningful heterogeneity across counties, where certain childcare cost and provider dominance patterns are associated with lower female labor force participation, indicating potential gaps in childcare infrastructure that may constrain flexible work participation.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# scatterplot: provider advantage vs female LFP, colored by cluster
plt.figure(figsize=(7, 5))
sns.scatterplot(data=df_q2, x='provider_advantage', y='flfpr_20to64', hue='cluster_kmeans', alpha=0.7)
plt.axvline(0, linestyle='--', linewidth=1)  # the left and right sides of 0 represent which provider is more dominant
plt.title('Provider Advantage vs Female LFPR')
plt.xlabel('Provider advantage (Family Childcare - Center-Based care)')
plt.ylabel('Female LFPR (20–64)')
plt.legend(title='Cluster', bbox_to_anchor=(1.02, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# The clustering reveals heterogeneous patterns in how provider dominance relates to female labor force participation. Some counties show persistently low participation despite more affordable family childcare, suggesting potential gaps in childcare infrastructure and schedule flexibility.

# %% [markdown]
# ##### Hierarchical Clustering

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster

k_final = 4
Z_ward = linkage(Xs, method='ward')  # build linkage matrix: try ward linkage
Z_avg  = linkage(Xs, method='average')  # build linkage matrix: try average linkage

# plot dendrogram with cut line (Ward linkage)
plt.figure(figsize=(14, 5))
dendrogram(Z_ward, truncate_mode='lastp', p=30, show_leaf_counts=True)  # only display the last part, and up to 30 clusters
cut_height_ward = Z_ward[-(k_final-1), 2]  # mark the line with K clusters
plt.axhline(y=cut_height_ward, c='red', linestyle='--', label=f'Cut for k={k_final}')
plt.legend()
plt.title(f'Hierarchical Dendrogram (Ward linkage with cut at k = {k_final})')
plt.xlabel('Cluster (truncated)')
plt.ylabel('Distance')
plt.show()

# plot dendrogram with cut line (Average linkage)
plt.figure(figsize=(14, 5))
dendrogram(Z_avg, truncate_mode='lastp', p=30, show_leaf_counts=True)  # only display the last part, and up to 30 clusters
cut_height_avg = Z_avg[-(k_final-1), 2]  # mark the line with K clusters
plt.axhline(y=cut_height_avg, c='red', linestyle='--', label=f'Cut for k={k_final}')
plt.legend()
plt.title(f'Hierarchical Dendrogram (Average linkage with cut at k = {k_final})')
plt.xlabel('Cluster (truncated)')
plt.ylabel('Distance')
plt.show()

# %% [markdown]
# The Ward linkage produces well-balanced and clearly separated clusters when cut at k = 4, indicating meaningful structure in the data. In contrast, the Average linkage largely merges most counties into a single cluster, offering limited differentiation. Therefore, Ward linkage provides a more interpretable and reliable hierarchical clustering solution for this analysis.

# %% [markdown]
# ##### Compare K-means & Hierarchical Clustering

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster

# cut the hierarchical tree into k_final clusters
df_q2["cluster_hier_ward"] = fcluster(Z_ward, t=k_final, criterion="maxclust") - 1  # index starts from 0
df_q2["cluster_hier_avg"]  = fcluster(Z_avg,  t=k_final, criterion="maxclust") - 1  # index starts from 0

# compare consistency between K-means vs Hierarchical
print('Crosstab: K-means vs Hierarchical (Ward)')
display(pd.crosstab(df_q2['cluster_kmeans'], df_q2['cluster_hier_ward']))

print('Crosstab: K-means vs Hierarchical (Average)')
display(pd.crosstab(df_q2['cluster_kmeans'], df_q2['cluster_hier_avg']))
# Out:
# Crosstab: K-means vs Hierarchical (Ward)
# cluster_hier_ward    0     1    2    3
# cluster_kmeans
# 0                    3     0    0  187
# 1                    2    81  265   18
# 2                  829   144   63   84
# 3                   57  1343   14   54
# Crosstab: K-means vs Hierarchical (Average)
# cluster_hier_avg  0     1   2  3
# cluster_kmeans
# 0                 0   189   1  0
# 1                 4   358   3  1
# 2                 0  1103  17  0
# 3                 0  1468   0  0

# %% [markdown]
# The cross-table shows partial alignment between K-means and Ward hierarchical clustering, with some clusters mapping closely while others split across multiple groups. In contrast, the Average linkage results collapse most counties into a single cluster, offering limited discriminatory power.

# %% [markdown]
# # **Milestone 4 - Refine: Theme 4: Policy Interventions**

# %% [markdown]
# ### From the perspective of policy making, what are the main factors contributing to high childcare cost burden (as indicated by low childcare affordability), and what kind of customized policies can be introduced to these counties/areas?

# %% [markdown]
# #### Data Preprocessing - **Method 1: Impute missing values using the median**

# %%
# impute missing values using the median
df_median = merged_df.copy()

cols_to_impute = [
    'mcsa', 'mfccsa',
    'mc_infant', 'mfcc_infant',
    'mc_toddler', 'mfcc_toddler',
    'mc_preschool', 'mfcc_preschool'
]

for col in cols_to_impute:
  median_value = df_median[col].median()  # calculate median for each column
  df_median[col] = df_median[col].fillna(median_value)  # fill NA with median

print('Missing values after imputation:')
print(df_median[cols_to_impute].isna().sum())
# Out:
# Missing values after imputation:
# mcsa              0
# mfccsa            0
# mc_infant         0
# mfcc_infant       0
# mc_toddler        0
# mfcc_toddler      0
# mc_preschool      0
# mfcc_preschool    0
# dtype: int64

# %%
# merged toddler's columns and preschool's columns (take the mean)
df_median['mc_toddler_and_preschool'] = (df_median['mc_toddler'] + df_median['mc_preschool']) / 2
df_median['mfcc_toddler_and_preschool'] = (df_median['mfcc_toddler'] + df_median['mfcc_preschool']) / 2

df_median.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34567 entries, 0 to 34566
# Data columns (total 67 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   county_fips_code            34567 non-null  object
#  1   study_year                  34567 non-null  int64
#  2   unr_16                      34567 non-null  float64
#  3   funr_16                     34567 non-null  float64
#  4   munr_16                     34567 non-null  float64
#  5   unr_20to64                  34567 non-null  float64
#  6   funr_20to64                 34567 non-null  float64
#  7   munr_20to64                 34567 non-null  float64
#  8   flfpr_20to64                34567 non-null  float64
#  9   flfpr_20to64_under6         34567 non-null  float64
#  10  flfpr_20to64_6to17          34567 non-null  float64
#  11  flfpr_20to64_under6_6to17   34567 non-null  float64
#  12  mlfpr_20to64                34567 non-null  float64
# ...

# %% [markdown]
# #### Affordability Ratio

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# calculate affordability ratios (childcare cost / income)
# define variable groups
age_groups = ['infant', 'toddler_and_preschool', 'sa']
care_types = ['mc', 'mfcc']
care_type_name = {'mc': 'center', 'mfcc': 'family'}

# create a subplot with 2 rows x 3 columns
fig, axes = plt.subplots(2, 3, figsize=(22, 10), sharex=True)
fig.suptitle('Affordability Ratios Across All Age Groups', fontsize=18)

for i, c_type in enumerate(care_types):
  for j, age in enumerate(age_groups):

    if age == 'sa':
      col_name = f'{c_type}{age}'
    else:
      col_name = f'{c_type}_{age}'

    ratio_col = f'{col_name}_ratio'  # for creating new columns

    # convert childcare cost to yearly price and divided by yearly income
    df_median[ratio_col] = (df_median[col_name] * 52) / df_median['mhi_2018']

    # plot histogram
    sns.histplot(df_median[ratio_col], kde=True, ax=axes[i, j], color='skyblue' if c_type=='mc' else 'orange')
    axes[i, j].set_title(f'{care_type_name[c_type]} - {age}')
    axes[i, j].set_xlabel('Affordability Ratio')
    axes[i, j].set_ylabel('Number of Counties')

    # mark the 10% affordability threshold
    axes[i, j].axvline(0.1, color='red', linestyle='--')

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %% [markdown]
# Based on imputing missing values using the median, these histograms illustrate the distribution of affordability ratios across counties by 2 childcare types (center-based and family-based) and 3 age groups (infant, toddler and preschool, and school-age). The affordability ratio is defined as childcare cost divided by household income. The red dashed line represents the 10% affordability threshold traditionally defined by the U.S. Department of Health and Human Services (HHS, https://www.federalregister.gov/documents/2016/09/30/2016-22986/child-care-and-development-fund-ccdf-program). Across all 6 categories, the area to the right of the red line represents a substantial proportion of counties where childcare costs are considered unaffordable.
#
# For the infant group, the distribution of center-based childcare is shifted furthest to the right among the six subplots. This indicates that center-based infant care imposes a substantially higher financial burden on median-income households compared to other age groups and care types.
#
# As children transition from infancy to school age, the peak of the distribution shifts slightly to the left, suggesting a reduction in cost pressure. However, the long right tail persists, highlighting that childcare remains financially burdensome in many counties regardless of the child’s age.
#
# These results are highly consistent with the findings from Milestone 2.

# %% [markdown]
# #### Affordability Deviation From Norms

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# define variable groups (the same as affordability ratio analysis)
age_groups = ['infant', 'toddler_and_preschool', 'sa']
care_types = ['mc', 'mfcc']
ratio_cols = ['mc_infant_ratio', 'mfcc_infant_ratio',
        'mc_toddler_and_preschool_ratio', 'mfcc_toddler_and_preschool_ratio',
        'mcsa_ratio', 'mfccsa_ratio']

# calculate the average affordability ratio for each county across years
county_avg = df_median.groupby(['county_name', 'state_name'])[ratio_cols].mean().reset_index()

# calculate the z-score of each county in its state
def zscore(x):
    return (x - x.mean()) / x.std()

z_cols = []
for col in ratio_cols:
    z_col = f'z_{col}'
    county_avg[z_col] = county_avg.groupby('state_name')[col].transform(zscore)
    z_cols.append(z_col)

# find the most anomalous counties by the max |z| across columns
county_avg['max_abs_z'] = county_avg[z_cols].abs().max(axis=1)  # pick the max |z| for each z_col

top_n = 20  # pick the top 20 counties
top_df = county_avg.nlargest(top_n, 'max_abs_z').copy()

# plot heatmap: rows = counties, columns = ratios
top_df['county_state'] = top_df['county_name'] + ', ' + top_df['state_name']
heatmap_data = top_df.set_index('county_state')[z_cols]

plt.figure(figsize=(14, 10))
sns.heatmap(heatmap_data, cmap='coolwarm', center=0, linewidths=0.3, linecolor='white')
plt.title(f'Deviation from State Norms (Z-scores) — Top {top_n} Most Anomalous Counties (imputing)')
plt.xlabel('Care Type & Age Group (Z-score of Affordability Ratio within State)')
plt.ylabel('County, State')
plt.tight_layout()
plt.show()

# %% [markdown]
# After imputing missing values using the median and merging the toddler and preschool age groups, the results are slightly different from those in Milestone 2.
#
# This heatmap presents the deviation of affordability ratios from state norms (measured in z-scores) for the top 20 most anomalous counties. State norms were calculated by taking the mean affordability ratio within each state for the two childcare types across each age group.
#
# The most extreme case is Brooks County, Texas, where affordability ratios across all categories are significantly higher than the state averages. This suggests that Brooks County experiences the most severe childcare affordability burden relative to other counties within the same state.
#
# In contrast, Williamson County, Tennessee, and Hamilton County, Indiana, show consistently negative z-scores, indicating a relatively lower childcare burden compared to their respective state norms.
#
# Additionally, DeKalb County and Cook County, Illinois, exhibit notably higher affordability ratios for school-age childcare. This differs from the general pattern observed in the histogram analysis, where school-age care typically imposes a lower financial burden.

# %% [markdown]
# #### Clustering

# %%
import numpy as np
import pandas as pd

# representation
rep_cols = [
    'mc_infant_ratio', 'mfcc_infant_ratio',
    'mc_toddler_and_preschool_ratio', 'mfcc_toddler_and_preschool_ratio',
    'mcsa_ratio', 'mfccsa_ratio',
    'pr_f'
]

# prepare dataframe for clustering
id_cols = ['county_fips_code', 'county_name', 'state_name']
df_cluster = (df_median[id_cols + rep_cols]
        .groupby(id_cols, as_index=False)[rep_cols]
        .mean())  # take the mean of each representative

print(f'df_cluster shape: {df_cluster.shape}')
df_cluster.info()
df_cluster.head()
# Out:
# df_cluster shape: (3144, 10)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3144 entries, 0 to 3143
# Data columns (total 10 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   county_fips_code                  3144 non-null   object
#  1   county_name                       3144 non-null   object
#  2   state_name                        3144 non-null   object
#  3   mc_infant_ratio                   3144 non-null   float64
#  4   mfcc_infant_ratio                 3144 non-null   float64
#  5   mc_toddler_and_preschool_ratio    3144 non-null   float64
#  6   mfcc_toddler_and_preschool_ratio  3144 non-null   float64
#  7   mcsa_ratio                        3144 non-null   float64
#  8   mfccsa_ratio                      3144 non-null   float64
#  9   pr_f                              3144 non-null   float64
# dtypes: float64(7), object(3)
# memory usage: 245.8+ KB
# ...

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# feature matrix
X = df_cluster[rep_cols].copy()

# build a pre-processing pipeline
prep_pipeline = Pipeline(steps=[('scaler', StandardScaler())])  # normalize: mean = 0, sd = 1

# transform data
Xs_std = prep_pipeline.fit_transform(X)

print(f'Xs_std shape: {Xs_std.shape}')
# Out:
# Xs_std shape: (3144, 7)

# %%
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer

# determine the number of clusters
clustering = KMeans(random_state=42)
visualizer = KElbowVisualizer(clustering, k=(2, 11),  # try k = 2 to 10
                metric='silhouette', timings=False, random_state=42)

visualizer.fit(Xs_std)  # fit the data to the visualizer
visualizer.show()
# Out:
# <Axes: title={'center': 'Silhouette Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='silhouette score'>

# %% [markdown]
# According to the silhouette score results for K-means clustering, the highest score (0.416) is achieved when K=2. After K=2, the silhouette score decreases sharply as the number of clusters increases.
#
# This suggests that dividing the data into 2 clusters provides the most well-defined and well-separated grouping structure among the tested values of K. Therefore, K=2 appears to be the optimal choice.

# %%
from sklearn.cluster import KMeans

# initialize KMeans model (n_cluster = 2)
kmeans = KMeans(n_clusters=2, random_state=42)

# fit the model and predict cluster labels, excluding the existing 'cluster_labels' column
df_cluster['cluster_labels'] = kmeans.fit_predict(Xs_std).astype(str)

# display the value counts of the new cluster labels
print(df_cluster['cluster_labels'].value_counts())
# Out:
# cluster_labels
# 0    1951
# 1    1193
# Name: count, dtype: int64

# %%
# plot the result of clustering
sns.pairplot(df_cluster, hue='cluster_labels', kind='hist', diag_kind='kde', corner=True, palette='Set2',
    plot_kws={'alpha': 0.7}, diag_kws={'alpha': 0.7}
    )

# %% [markdown]
# **1. Systemic Affordability Crisis Across Age Groups**
#
# The pairplot reveals a highly synchronized diagonal distribution among affordability ratios across different age groups, particularly the strong correlation between infant care costs and toddler-and-preschool care costs. This synchronization suggests that childcare burdens are not isolated to a specific developmental stage but are systemic across the entire childhood spectrum. From a policy perspective, this implies that interventions targeting only a single age group may be insufficient. Because the childcare crisis persists from infancy through school age within the same county profiles, a comprehensive, multi-age subsidy framework is required to provide continuous economic relief to families.
#
# **2. Structural Dichotomy and the Poverty Trap**
#
# The optimal clustering at K=2 identifies a stark, binary market structure across US counties: the "Low burden / Low Poverty" group versus the "High burden / High Poverty" group. A critical insight from the "Mismatch Zones" is the strong overlap between high family poverty rates (pr_f) and high affordability ratios. This finding challenges the assumption that low-income areas necessarily benefit from a lower cost of living. Instead, in these regions, childcare consumes a disproportionately large share of families’ limited incomes. This severe mismatch between infrastructure costs and economic capacity highlights areas where the market has fundamentally failed to provide accessible childcare.
#
# **3. Targeted Policy Interventions for High-Crisis Clusters**
#
# Cluster 1 is generally positioned to the right of Cluster 0 and includes the outliers in the upper-right corner of the poverty–affordability scatter plots. These counties represent the most severe cases of economic–infrastructure mismatch. Within this cluster, infant care ratios display the most extreme outlier patterns, indicating that infant care costs are the primary driver of household financial strain in high-burden counties.

# %% [markdown]
# #### Data Preprocessing - **Method 2: Drop missing values**

# %%
# drop missing values
df_drop = merged_df.copy()

cols_to_drop = [
    'mcsa', 'mfccsa',
    'mc_infant', 'mfcc_infant',
    'mc_toddler', 'mfcc_toddler',
    'mc_preschool', 'mfcc_preschool'
]

df_drop = df_drop.dropna(subset=cols_to_drop)

print('Missing values after dropping:')
print(df_drop[cols_to_drop].isna().sum())
# Out:
# Missing values after dropping:
# mcsa              0
# mfccsa            0
# mc_infant         0
# mfcc_infant       0
# mc_toddler        0
# mfcc_toddler      0
# mc_preschool      0
# mfcc_preschool    0
# dtype: int64

# %%
# merged toddler's columns and preschool's columns (take the mean)
df_drop['mc_toddler_and_preschool'] = (df_drop['mc_toddler'] + df_drop['mc_preschool']) / 2
df_drop['mfcc_toddler_and_preschool'] = (df_drop['mfcc_toddler'] + df_drop['mfcc_preschool']) / 2

df_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23342 entries, 0 to 34566
# Data columns (total 67 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   county_fips_code            23342 non-null  object
#  1   study_year                  23342 non-null  int64
#  2   unr_16                      23342 non-null  float64
#  3   funr_16                     23342 non-null  float64
#  4   munr_16                     23342 non-null  float64
#  5   unr_20to64                  23342 non-null  float64
#  6   funr_20to64                 23342 non-null  float64
#  7   munr_20to64                 23342 non-null  float64
#  8   flfpr_20to64                23342 non-null  float64
#  9   flfpr_20to64_under6         23342 non-null  float64
#  10  flfpr_20to64_6to17          23342 non-null  float64
#  11  flfpr_20to64_under6_6to17   23342 non-null  float64
#  12  mlfpr_20to64                23342 non-null  float64
# ...

# %% [markdown]
# #### Affordability Ratio

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# calculate affordability ratios (childcare cost / income)
# define variable groups
age_groups = ['infant', 'toddler_and_preschool', 'sa']
care_types = ['mc', 'mfcc']
care_type_name = {'mc': 'center', 'mfcc': 'family'}

# create a subplot with 2 rows x 3 columns
fig, axes = plt.subplots(2, 3, figsize=(22, 10), sharex=True)
fig.suptitle('Affordability Ratios Across All Age Groups', fontsize=18)

for i, c_type in enumerate(care_types):
  for j, age in enumerate(age_groups):

    if age == 'sa':
      col_name = f'{c_type}{age}'
    else:
      col_name = f'{c_type}_{age}'

    ratio_col = f'{col_name}_ratio'  # for creating new columns

    # convert childcare cost to yearly price and divided by yearly income
    df_drop[ratio_col] = (df_drop[col_name] * 52) / df_drop['mhi_2018']

    # plot histogram
    sns.histplot(df_drop[ratio_col], kde=True, ax=axes[i, j], color='pink' if c_type=='mc' else 'lightgreen')
    axes[i, j].set_title(f'{care_type_name[c_type]} - {age}')
    axes[i, j].set_xlabel('Affordability Ratio')
    axes[i, j].set_ylabel('Number of Counties')

    # mark the 10% affordability threshold
    axes[i, j].axvline(0.1, color='red', linestyle='--')

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %% [markdown]
# After dropping missing values, I calculated the affordability ratios for the two childcare types across each age group. The affordability ratio is defined as childcare cost divided by household income, consistent with the definition used in Milestone 2.
#
# Overall, the results show patterns similar to those obtained using median imputation. Center-based childcare imposes a greater financial burden than family-based childcare in most counties. In addition, most counties exhibit higher affordability ratios for infant care. As children grow older, the financial burden generally decreases.

# %% [markdown]
# #### Affordability Deviation From Norms

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# define variable groups (the same as affordability ratio analysis)
age_groups = ['infant', 'toddler_and_preschool', 'sa']
care_types = ['mc', 'mfcc']
ratio_cols = ['mc_infant_ratio', 'mfcc_infant_ratio',
        'mc_toddler_and_preschool_ratio', 'mfcc_toddler_and_preschool_ratio',
        'mcsa_ratio', 'mfccsa_ratio']

# calculate the average affordability ratio for each county across years
county_avg = df_drop.groupby(['county_name', 'state_name'])[ratio_cols].mean().reset_index()

# calculate the z-score of each county in its state
def zscore(x):
    return (x - x.mean()) / x.std()

z_cols = []
for col in ratio_cols:
    z_col = f'z_{col}'
    county_avg[z_col] = county_avg.groupby('state_name')[col].transform(zscore)
    z_cols.append(z_col)

# find the most anomalous counties by the max |z| across columns
county_avg['max_abs_z'] = county_avg[z_cols].abs().max(axis=1)  # pick the max |z| for each z_col

top_n = 20  # pick the top 20 counties
top_df = county_avg.nlargest(top_n, 'max_abs_z').copy()

# plot heatmap: rows = counties, columns = ratios
top_df['county_state'] = top_df['county_name'] + ', ' + top_df['state_name']
heatmap_data = top_df.set_index('county_state')[z_cols]

plt.figure(figsize=(14, 10))
sns.heatmap(heatmap_data, cmap='coolwarm', center=0, linewidths=0.3, linecolor='white')
plt.title(f'Deviation from State Norms (Z-scores) — Top {top_n} Most Anomalous Counties (dropping)')
plt.xlabel('Care Type & Age Group (Z-score of Affordability Ratio within State)')
plt.ylabel('County, State')
plt.tight_layout()
plt.show()

# %% [markdown]
# The ranking of the top 20 anomalous counties differs noticeably between the median imputation approach and the dropping approach. Although both analyses use the same underlying dataset and anomaly detection logic (state-level z-scores of affordability ratios), the preprocessing decision significantly affects the results.
#
# As the heatmap shows, the list of the top 20 most anomalous counties differs from that obtained using the median imputation approach. Some counties are newly included under the dropping approach. Moreover, under the dropping approach, the most extreme case is Bronx County, New York, rather than Brooks County, Texas.
#
# **The possible reasons for this difference are as follows:**
#
# *   First, the two methods **alter the effective sample size**. Median imputation preserves all counties by filling missing values with the state-level median, while dropping removes any county with missing observations in the selected variables. As a result, the candidate pool of counties used to compute within-state means and standard deviations differs between the two approaches. This change in sample composition directly affects anomaly rankings.
# *   Second, because **z-scores** depend on the state mean and standard deviation, any change in dispersion affects anomaly rankings. Median imputation introduces values near the median, potentially compressing variance and inflating z-scores for already high-burden counties. In contrast, dropping missing values changes both the mean and standard deviation by removing observations, leading to shifts in z-score magnitudes and county rankings.
# *   Third, **missingness may not be random**. Counties with incomplete data may systematically differ in size, urbanization level, or data-reporting quality. Median imputation retains these counties and treats their missing values as typical, while dropping excludes them entirely. Therefore, the two approaches may capture slightly different structural patterns rather than purely statistical differences.

# %% [markdown]
# #### Clustering

# %%
import numpy as np
import pandas as pd

# representation
rep_cols = [
    'mc_infant_ratio', 'mfcc_infant_ratio',
    'mc_toddler_and_preschool_ratio', 'mfcc_toddler_and_preschool_ratio',
    'mcsa_ratio', 'mfccsa_ratio',
    'pr_f'
]

# prepare dataframe for clustering
id_cols = ['county_fips_code', 'county_name', 'state_name']
df_cluster = (df_drop[id_cols + rep_cols]
        .groupby(id_cols, as_index=False)[rep_cols]
        .mean())  # take the mean of each representative

print(f'df_cluster shape: {df_cluster.shape}')
df_cluster.info()
df_cluster.head()
# Out:
# df_cluster shape: (2885, 10)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2885 entries, 0 to 2884
# Data columns (total 10 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   county_fips_code                  2885 non-null   object
#  1   county_name                       2885 non-null   object
#  2   state_name                        2885 non-null   object
#  3   mc_infant_ratio                   2885 non-null   float64
#  4   mfcc_infant_ratio                 2885 non-null   float64
#  5   mc_toddler_and_preschool_ratio    2885 non-null   float64
#  6   mfcc_toddler_and_preschool_ratio  2885 non-null   float64
#  7   mcsa_ratio                        2885 non-null   float64
#  8   mfccsa_ratio                      2885 non-null   float64
#  9   pr_f                              2885 non-null   float64
# dtypes: float64(7), object(3)
# memory usage: 225.5+ KB
# ...

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# feature matrix
X = df_cluster[rep_cols].copy()

# build a pre-processing pipeline
prep_pipeline = Pipeline(steps=[('scaler', StandardScaler())])  # normalize: mean = 0, sd = 1

# transform data
Xs_std = prep_pipeline.fit_transform(X)

print(f'Xs_std shape: {Xs_std.shape}')
# Out:
# Xs_std shape: (2885, 7)

# %%
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer

# determine the number of clusters
clustering = KMeans(random_state=42)
visualizer = KElbowVisualizer(clustering, k=(2, 11),  # try k = 2 to 10
                metric='silhouette', timings=False, random_state=42)

visualizer.fit(Xs_std)  # fit the data to the visualizer
visualizer.show()
# Out:
# <Axes: title={'center': 'Silhouette Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='silhouette score'>

# %% [markdown]
# Based on the silhouette score results for K-means clustering, even when using the dropping approach, the silhouette score is highest at K=2 (0.398). Subsequently, the silhouette coefficient decreases sharply as the number of clusters increases.
#
# Therefore, I decided on a cluster size of 2, and applied this to subsequent clustering analysis.

# %%
from sklearn.cluster import KMeans

# initialize KMeans model (n_cluster = 2)
kmeans = KMeans(n_clusters=2, random_state=42)

# fit the model and predict cluster labels, excluding the existing 'cluster_labels' column
df_cluster['cluster_labels'] = kmeans.fit_predict(Xs_std).astype(str)

# display the value counts of the new cluster labels
print(df_cluster['cluster_labels'].value_counts())
# Out:
# cluster_labels
# 1    1850
# 0    1035
# Name: count, dtype: int64

# %%
# plot the result of clustering
sns.pairplot(df_cluster, hue='cluster_labels', kind='hist', diag_kind='kde', corner=True, palette='Set1',
    plot_kws={'alpha': 0.7}, diag_kws={'alpha': 0.7}
    )

# %% [markdown]
# The pairplot shows the clustering outcomes based on the approach of dropping missing values. Overall, the patterns are largely consistent with those obtained using the median imputation approach, despite the exclusion of missing data.
#
# This result further indicates that childcare affordability burdens are highly synchronized across age groups, suggesting that cost pressures are systemic rather than age-specific and therefore require comprehensive policy responses. Infant care costs emerge as the primary driver of financial strain, highlighting the need for targeted interventions in high-mismatch counties.

# %% [markdown]
# #### Conclusion

# %% [markdown]
# In Milestone 4, I compared the impact of different missing value handling methods on clustering results, specifically median imputation and dropping missing values, with merging the toddler and preschool age groups. The analysis revealed that although the missing value handling methods differed, the overall patterns of the results remained similar. Two main clusters with comparable sizes were consistently identified: a High burden / High poverty group and a Low burden / Low poverty group. Furthermore, the childcare burden was observed to decrease relatively as child age increased.
#
# Notably, the different missing value handling methods led to changes in the list of the top 20 most anomalous counties. The median imputation approach, which replaces all missing values with the median, resulted in more observations being concentrated around the center of the distribution, thereby reducing overall variance. However, counties that deviated substantially from the median exhibited amplified differences in the z-score calculations.
#
# In contrast, the dropping approach removed approximately 30% of the observations with missing values. Although this method is statistically faithful to the observed data, missing values may not be randomly distributed and could be concentrated in specific counties. As a result, removing these observations altered the set of counties included in the comparison, which explains why the two methods produced different lists of the top 20 anomalous counties.
#
# From a policy perspective, governments should prioritize counties within the High burden / High poverty cluster, as these areas demonstrate the most severe mismatch between childcare costs and household economic capacity. Moreover, childcare infrastructure and subsidy programs should cover children from infancy through school age rather than focusing solely on infant care. As shown in the pairplot analysis, high childcare burden is a structural issue. If infant care costs are high in a given county, costs for toddlers, preschoolers, and school-age children tend to be elevated as well. Therefore, policymakers should adjust resource allocation toward High burden / High poverty counties, particularly the top 20 counties exhibiting the greatest resource mismatch, and ensure that support is distributed across all age groups.
